# %%
from langchain_core.messages import AIMessage

ia_message = AIMessage(content="Message from de AI")
ia_message.text
# Out:
# 'Message from de AI'

# %%
from langchain_core.messages import HumanMessage

human_message = HumanMessage(content="Message from the human")
human_message.text
# Out:
# 'Message from the human'

# %%
history = [ia_message, human_message]

for message in history:
    message.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Message from de AI
# ================================ Human Message =================================
#
# Message from the human

# %%
history + [AIMessage(content="New message from de AI")]
# Out:
# [AIMessage(content='Message from de AI', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='Message from the human', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='New message from de AI', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]
